# %%
import pageviewapi
pageviewapi.top('fr.wikipedia', 2023, '06', 18, access='all-access')
# Out:
# AttrDict({'items': [{'project': 'fr.wikipedia', 'access': 'all-access', 'year': '2023', 'month': '06', 'day': '18', 'articles': [{'article': 'Cookie_(informatique)', 'views': 1108041, 'rank': 1}, {'article': 'Wikipédia:Accueil_principal', 'views': 567031, 'rank': 2}, {'article': 'Spécial:Recherche', 'views': 106052, 'rank': 3}, {'article': 'Luis_Enrique', 'views': 61520, 'rank': 4}, {'article': 'Amanda_Lear', 'views': 51036, 'rank': 5}, {'article': 'Missak_Manouchian', 'views': 42541, 'rank': 6}, {'article': 'Fête_des_Pères', 'views': 33589, 'rank': 7}, {'article': "Ligue_des_nations_de_l'UEFA", 'views': 31500, 'rank': 8}, {'article': 'Appel_du_18_Juin', 'views': 27399, 'rank': 9}, {'article': 'Paul_Newman', 'views': 27203, 'rank': 10}, {'article': 'Bouclier_de_Brennus', 'views': 21654, 'rank': 11}, {'article': 'Hombre_(film)', 'views': 19543, 'rank': 12}, {'article': 'Victor_Belmondo', 'views': 19405, 'rank': 13}, {'article': 'Facebook', 'views': 18654, 'rank': 14}, {'article': 'Rob
# ...

# %%
pageviewapi.per_article('en', limit=200)
